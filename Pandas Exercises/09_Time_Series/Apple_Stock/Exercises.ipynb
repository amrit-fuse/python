# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %%
url='https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv'

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %%
apple = pd.read_csv(url)

apple.to_csv('apple.csv', index=False)

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
apple['Date'] = pd.to_datetime(apple['Date'])
apple.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
apple.set_index('Date', inplace=True)
apple.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
apple.index.is_unique
# Out:
# True

# %% [markdown]
# ### Step 8.  Ops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
apple=apple.sort_index(ascending=True)
apple.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
# 1. Get the last business day of each month
apple.resample('BM').sum()
#resample('BM') is used to get the last business day of each month i.e group by month and get the last day of each month
# Out:
#                 Open      High       Low     Close      Volume  Adj Close
# Date
# 1980-12-31    396.26    397.38    395.76    395.76   336212800       6.15
# 1981-01-30    666.85    668.36    664.75    664.75   152247200      10.37
# 1981-02-27    503.12    504.87    501.75    501.75    80404800       7.81
# 1981-03-31    548.63    550.37    546.40    546.40   175179200       8.53
# 1981-04-30    573.02    574.73    571.77    571.77   134232000       8.89
# ...              ...       ...       ...       ...         ...        ...
# 2014-03-31  11205.46  11265.53  11131.49  11197.50  1250424700    1590.75
# 2014-04-30  11341.72  11431.33  11261.51  11362.56  1608765200    1614.21
# 2014-05-30  12627.34  12733.83  12564.99  12667.11  1433917100    1807.23
# 2014-06-30   4669.56   4705.77   4635.45   4675.82  1206556300    1929.60
# 2014-07-31    471.47    475.02    467.44    472.35   210918300     472.35
#
# [404 rows x 6 columns]

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
#what is the difference in days between the first day and the oldest

apple.index.max() - apple.index.min()
# Out:
# Timedelta('12261 days 00:00:00')

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
#how many months in the data  we have ?

apple.groupby(apple.index.month).count().sum()
# Out:
# Open         8465
# High         8465
# Low          8465
# Close        8465
# Volume       8465
# Adj Close    8465
# dtype: int64

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
apple['Adj Close'].plot(figsize=(13.5,9))
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
apple['2009']['Adj Close'].plot(figsize=(13.5,9)) #plotting the adj close for the year 2009
# Out:
# C:\Users\amrit\AppData\Local\Temp\ipykernel_16132\3300213488.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   apple['2009']['Adj Close'].plot(figsize=(13.5,9))
# <AxesSubplot: xlabel='Date'>
